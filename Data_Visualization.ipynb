# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyalakshmikandimalla/Calculator/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as pit

# %%
import matplotlib.pyplot as plt
subjects=['python','Java','C++','SQL']
students=[45,38,30,50]
plt.bar(subjects,students)
plt.title("students Enrolled")
plt.xlabel("subjects")
# Out:
# Text(0.5, 0, 'subjects')

# %%
plt.bar(x,height)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3318/3744062411.py in <cell line: 0>()
# ----> 1 plt.bar(x,height)
#
# NameError: name 'x' is not defined

# %%
plt.bar(subjects,students,color='green')
plt.show()

# %%
months=['Jan','Feb','Mar','Apr','May']
sales=[25,30,40,35,50]
plt.plot(months,sales)
plt.title("Montly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %%
plt.plot(months,sales,
         marker='o',
         linestyle='--',
         color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt
study_hours=[1,2,3,4,5,6,7]
marks=[35,40,50,60,68,80,90]
plt.scatter(study_hours,marks)
plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y,marker='s')
plt.title("Square Marker")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y,marker='^')
plt.title("Triangle Marker")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y,marker='D')
plt.title("Diamond Marker")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y,marker='*',s=50)

plt.title("Star Marker")
plt.show()

# %%
labels=['Python','Java','C++','SQL']
students=[40,30,20,10]
plt.pie(students,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90)
plt.title("Students Learning Prigramming Languages")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1368/1413519668.py in <cell line: 0>()
#       1 labels=['Python','Java','C++','SQL']
#       2 students=[40,30,20,10]
# ----> 3 plt.pie(students,
#       4         labels=labels,
#       5         autopct='%1.1f%%',
#
# NameError: name 'plt' is not defined
